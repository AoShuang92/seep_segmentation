# seep_detection/train_images_256/045594.000076.tif
# seep_detection/train_images_256/045594.000088.tif
# seep_detection/train_images_256/045594.000068.tif
# seep_detection/train_images_256/045594.000089.tif
# seep_detection/train_images_256/045594.000094.tif
# seep_detection/train_images_256/045594.000097.tif
# seep_detection/train_images_256/045594.000109.tif
# seep_detection/train_images_256/045594.000108.tif
# seep_detection/train_images_256/045594.000127.tif
# seep_detection/train_images_256/045594.000117.tif
# seep_detection/train_images_256/045594.000115.tif
# seep_detection/train_images_256/045594.000129.tif
# seep_detection/train_images_256/045594.000130.tif
# seep_detection/train_images_256/045594.000134.tif
# seep_detection/train_images_256/045594.000131.tif
# seep_detection/train_images_256/045594.000136.tif
# seep_detection/train_images_256/045594.000148.tif
# seep_detection/train_images_256/045594.000147.tif
# seep_detection/train_images_256/045594.000151.tif
# seep_detection/train_images_256/045594.000156.tif
# seep_detection/train_images_256/045594.000149.tif
# seep_detection/train_images_256/045594.000169.tif
# seep_detection/train_images_256/045594.000168.tif
# seep_detection/train_images_256/045594.000174.tif
# seep_detection/train_images_256/045594.000170.tif
# seep_detection/train_images_256/045594.000173.tif
# seep_detection/train_images_256/045594.000171.tif
# seep_detection/train_images_256/045594.000175.tif
# seep_detection/train_images_256/045594.000176.tif
# seep_detection/train_images_256/045594.000189.tif
# seep_detection/train_images_256/045594.000193.tif
# seep_detection/train_images_256/045594.000208.tif
# seep_detection/train_images_256/045594.000190.tif
# seep_detection/train_images_256/045594.000209.tif
# seep_detection/train_images_256/045594.000210.tif
# seep_detection/train_images_256/045594.000213.tif
# seep_detection/train_images_256/045594.000229.tif
# seep_detection/train_images_256/045594.000249.tif
# seep_detection/train_images_256/045594.000253.tif

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from torch import optim
import torch.nn.functional as F
from glob import glob
import csv
import random
import re
import os
from PIL import Image
import numpy as np
import sklearn.metrics

def seed_everything(seed=27):
  
  torch.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  np.random.seed(seed)
  os.environ['PYTHONHASHSEED'] = str(seed)
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = False

# %% [markdown]
# Model Architecture: U-Net

# %%
def double_conv(in_channels, out_channels):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, padding=1),
        nn.ReLU(inplace=True),
        nn.Conv2d(out_channels, out_channels, 3, padding=1),
        nn.ReLU(inplace=True)
    )   


class UNet(nn.Module):

    def __init__(self, n_class=8):
        super().__init__()
                
        self.dconv_down1 = double_conv(3, 64)
        self.dconv_down2 = double_conv(64, 128)
        self.dconv_down3 = double_conv(128, 256)
        self.dconv_down4 = double_conv(256, 512)        

        self.maxpool = nn.MaxPool2d(2)
        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)        
        
        self.dconv_up3 = double_conv(256 + 512, 256)
        self.dconv_up2 = double_conv(128 + 256, 128)
        self.dconv_up1 = double_conv(128 + 64, 64)
        
        self.conv_last = nn.Conv2d(64, n_class, 1)
        
        
    def forward(self, x):
        conv1 = self.dconv_down1(x)
        x = self.maxpool(conv1)

        conv2 = self.dconv_down2(x)
        x = self.maxpool(conv2)
        
        conv3 = self.dconv_down3(x)
        x = self.maxpool(conv3)   
        
        x = self.dconv_down4(x)
        
        x = self.upsample(x)        
        x = torch.cat([x, conv3], dim=1)
        
        x = self.dconv_up3(x)
        x = self.upsample(x)        
        x = torch.cat([x, conv2], dim=1)       

        x = self.dconv_up2(x)
        x = self.upsample(x)        
        x = torch.cat([x, conv1], dim=1)   
        
        x = self.dconv_up1(x)
        
        out = self.conv_last(x)
        
        return out

# %%
import cv2
import torchvision.transforms.functional as TF
import torchvision.transforms as transforms

class image_seg(Dataset):
    def __init__(self, data_dir='', istrain = False, valid_ratio=0.2):
        self.dirs_all =glob(data_dir) 
        self.valid_ratio = valid_ratio
        self.istrain = istrain
        if istrain:
            self.dirs = self.dirs_all[int(len(self.dirs_all)*self.valid_ratio):]
        else:
            self.dirs = self.dirs_all[0:int(len(self.dirs_all)*self.valid_ratio)]

    def __len__(self):
        return len(self.dirs)
    def __getitem__(self, idx):
        input = cv2.imread(self.dirs[idx])
        filename = os.path.basename(self.dirs[idx])
        common_dir = os.path.dirname(os.path.dirname(self.dirs[idx]))
        label_dir = common_dir +'/train_masks_256/'+filename
        label = cv2.imread(label_dir)
        label = label[:,:,0]
        input = Image.fromarray(input)
        label = Image.fromarray(label)
        if self.istrain:
            if random.random() > 0.5:             
                input = TF.vflip(input)         
                label = TF.vflip(label)
        
        input = transforms.ToTensor()(input)
        label = transforms.ToTensor()(label).long()
        return input/255, label

# %% [markdown]
# Dataloader

# %%
import cv2
import torchvision.transforms.functional as TF

class image_seg(Dataset):
    def __init__(self, data_dir='', istrain = False, valid_ratio=0.2):
        self.dirs_all =glob(data_dir) 
        self.valid_ratio = valid_ratio
        self.istrain = istrain
        if istrain:
            self.dirs = self.dirs_all[int(len(self.dirs_all)*self.valid_ratio):]
        else:
            self.dirs = self.dirs_all[0:int(len(self.dirs_all)*self.valid_ratio)]

    def __len__(self):
        return len(self.dirs)
    def __getitem__(self, idx):
        input = cv2.imread(self.dirs[idx])
        input = input.transpose(2,0,1)
        filename = os.path.basename(self.dirs[idx])
        common_dir = os.path.dirname(os.path.dirname(self.dirs[idx]))
        label_dir = common_dir +'/train_masks_256/'+filename
        label = cv2.imread(label_dir)
        label = label.transpose(2,0,1)
        label = label[0]
        if self.istrain:
            if random.random() > 0.5:
                input = np.flip(input,axis=1).copy()
                label = np.flip(label,axis=0).copy()

        label = torch.tensor(label).long()
        input = torch.tensor(input).float()
        return input/255, label

# %% [markdown]
# Training Script

# %%
def train (model, train_loader, criterion, optimizer):
    model.train()
    sum_loss = 0
    
    for inputs,labels in train_loader:
        optimizer.zero_grad()
        inputs = inputs.to(device)
        labels = labels.squeeze(1).to(device)
        logits = model(inputs)
        loss = criterion(logits,labels)
        sum_loss += loss.item()
        loss.backward()
        optimizer.step()
        
def valid (model, valid_loader,criterion):
    model.eval()
    sum_loss = 0
    with torch.no_grad():
        for inputs,labels in valid_loader:
            inputs = inputs.to(device)
            labels = labels.squeeze(1).to(device)  
            logits = model(inputs)
            loss = criterion(logits,labels)
            sum_loss += loss.item()
    return sum_loss/len(valid_loader)

# %%
seed_everything()
batch_size = 4

Dataset_obj_train = image_seg(data_dir ='seep_detection/train_images_256/**.tif' , istrain = True,valid_ratio =0.2)
train_loader = DataLoader(Dataset_obj_train, batch_size= batch_size,shuffle=True, num_workers=2)

Dataset_obj_valid = image_seg(data_dir ='seep_detection/train_images_256/**.tif' , istrain = False,valid_ratio =0.2)
valid_loader = DataLoader(Dataset_obj_valid, batch_size= batch_size,shuffle=False, num_workers=2)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu') 
criterion = nn.CrossEntropyLoss()
model = UNet(n_class=8)
model.to(device)
optimizer = torch.optim.Adam(model.parameters())

epochs = 120
best_loss = float('inf')
best_epoch = 0

for epoch in range(epochs):
    train(model, train_loader, criterion, optimizer)
    loss = valid (model, valid_loader,criterion)
    if loss < best_loss:
        best_loss = loss
        best_epoch = epoch
        torch.save(model.state_dict(), 'best_model.pth')
    print('cur epoch:%d, cur loss:%.5f, best epoch:%d, best loss:%.4f'%(epoch,loss, best_epoch, best_loss))
# Out:
# cur epoch:0, cur loss:0.10164, best epoch:0, best loss:0.1016
# cur epoch:1, cur loss:0.10160, best epoch:1, best loss:0.1016
# cur epoch:2, cur loss:0.10172, best epoch:1, best loss:0.1016
# cur epoch:3, cur loss:0.10114, best epoch:3, best loss:0.1011
# cur epoch:4, cur loss:0.10010, best epoch:4, best loss:0.1001
# cur epoch:5, cur loss:0.10050, best epoch:4, best loss:0.1001
# cur epoch:6, cur loss:0.09895, best epoch:6, best loss:0.0990
# cur epoch:7, cur loss:0.09924, best epoch:6, best loss:0.0990
# cur epoch:8, cur loss:0.09780, best epoch:8, best loss:0.0978
# cur epoch:9, cur loss:0.09671, best epoch:9, best loss:0.0967
# cur epoch:10, cur loss:0.10005, best epoch:9, best loss:0.0967
# cur epoch:11, cur loss:0.10344, best epoch:9, best loss:0.0967
# cur epoch:12, cur loss:0.10475, best epoch:9, best loss:0.0967
# cur epoch:13, cur loss:0.09868, best epoch:9, best loss:0.0967
# cur epoch:14, cur loss:0.09616, best epoch:14, best loss:0.0962
# cur epoch:15, cur loss:0.09709, best epoch:14, best loss:0.0962
# cur epoch:16, cur loss:0.09353, best epoch:16, best loss:0.0935
# cur epoch:17, cur loss:0.09125, best epoch:17, best loss:0.0912
# cur epoch:18, cur loss:0.09350, best epoch:17, best loss:0.0912
# cur epoch:19, cur loss:0.12165, best epoch:17, best loss:0.0912
# cur epoch:20, cur loss:0.09896, best epoch:17, best loss:0.0912
# cur epoch:21, cur loss:0.09028, best epoch:21, best loss:0.0903
# cur epoch:22, cur loss:0.09059, best epoch:21, best loss:0.0903
# cur epoch:23, cur loss:0.08877, best epoch:23, best loss:0.0888
# cur epoch:24, cur loss:0.10456, best epoch:23, best loss:0.0888
# cur epoch:25, cur loss:0.09511, best epoch:23, best loss:0.0888
# cur epoch:26, cur loss:0.08844, best epoch:26, best loss:0.0884
# cur epoch:27, cur loss:0.08788, best epoch:27, best loss:0.0879
# cur epoch:28, cur loss:0.08822, best epoch:27, best loss:0.0879
# cur epoch:29, cur loss:0.09422, best epoch:27, best loss:0.0879
# cur epoch:30, cur loss:0.09576, best epoch:27, best loss:0.0879
# cur epoch:31, cur loss:0.09604, best epoch:27, best loss:0.0879
# cur epoch:32, cur loss:0.08778, best epoch:32, best loss:0.0878
# cur epoch:33, cur loss:0.08491, best epoch:33, best loss:0.0849
# cur epoch:34, cur loss:0.08771, best epoch:33, best loss:0.0849
# cur epoch:35, cur loss:0.08802, best epoch:33, best loss:0.0849
# cur epoch:36, cur loss:0.09185, best epoch:33, best loss:0.0849
# cur epoch:37, cur loss:0.08399, best epoch:37, best loss:0.0840
# cur epoch:38, cur loss:0.08951, best epoch:37, best loss:0.0840
# cur epoch:39, cur loss:0.08233, best epoch:39, best loss:0.0823
# cur epoch:40, cur loss:0.08210, best epoch:40, best loss:0.0821
# cur epoch:41, cur loss:0.08210, best epoch:40, best loss:0.0821
# cur epoch:42, cur loss:0.08409, best epoch:40, best loss:0.0821
# cur epoch:43, cur loss:0.08834, best epoch:40, best loss:0.0821
# cur epoch:44, cur loss:0.08758, best epoch:40, best loss:0.0821
# cur epoch:45, cur loss:0.08016, best epoch:45, best loss:0.0802
# cur epoch:46, cur loss:0.08125, best epoch:45, best loss:0.0802
# cur epoch:47, cur loss:0.08544, best epoch:45, best loss:0.0802
# cur epoch:48, cur loss:0.08062, best epoch:45, best loss:0.0802
# cur epoch:49, cur loss:0.07943, best epoch:49, best loss:0.0794
# cur epoch:50, cur loss:0.07735, best epoch:50, best loss:0.0773
# cur epoch:51, cur loss:0.07790, best epoch:50, best loss:0.0773
# cur epoch:52, cur loss:0.07890, best epoch:50, best loss:0.0773
# cur epoch:53, cur loss:0.07367, best epoch:53, best loss:0.0737
# cur epoch:54, cur loss:0.07318, best epoch:54, best loss:0.0732
# cur epoch:55, cur loss:0.07471, best epoch:54, best loss:0.0732
# cur epoch:56, cur loss:0.07263, best epoch:56, best loss:0.0726
# cur epoch:57, cur loss:0.08215, best epoch:56, best loss:0.0726
# cur epoch:58, cur loss:0.07214, best epoch:58, best loss:0.0721
# cur epoch:59, cur loss:0.07165, best epoch:59, best loss:0.0716
# cur epoch:60, cur loss:0.06982, best epoch:60, best loss:0.0698
# cur epoch:61, cur loss:0.07461, best epoch:60, best loss:0.0698
# cur epoch:62, cur loss:0.07301, best epoch:60, best loss:0.0698
# cur epoch:63, cur loss:0.07274, best epoch:60, best loss:0.0698
# cur epoch:64, cur loss:0.07148, best epoch:60, best loss:0.0698
# cur epoch:65, cur loss:0.06922, best epoch:65, best loss:0.0692
# cur epoch:66, cur loss:0.06936, best epoch:65, best loss:0.0692
# cur epoch:67, cur loss:0.06971, best epoch:65, best loss:0.0692
# cur epoch:68, cur loss:0.07324, best epoch:65, best loss:0.0692
# cur epoch:69, cur loss:0.06843, best epoch:69, best loss:0.0684
# cur epoch:70, cur loss:0.06843, best epoch:70, best loss:0.0684
# cur epoch:71, cur loss:0.07208, best epoch:70, best loss:0.0684
# cur epoch:72, cur loss:0.06962, best epoch:70, best loss:0.0684
# cur epoch:73, cur loss:0.06811, best epoch:73, best loss:0.0681
# cur epoch:74, cur loss:0.07022, best epoch:73, best loss:0.0681
# cur epoch:75, cur loss:0.06859, best epoch:73, best loss:0.0681
# cur epoch:76, cur loss:0.06900, best epoch:73, best loss:0.0681
# cur epoch:77, cur loss:0.06631, best epoch:77, best loss:0.0663
# cur epoch:78, cur loss:0.06893, best epoch:77, best loss:0.0663
# cur epoch:79, cur loss:0.06817, best epoch:77, best loss:0.0663
# cur epoch:80, cur loss:0.06732, best epoch:77, best loss:0.0663
# cur epoch:81, cur loss:0.06719, best epoch:77, best loss:0.0663
# cur epoch:82, cur loss:0.07174, best epoch:77, best loss:0.0663
# cur epoch:83, cur loss:0.07032, best epoch:77, best loss:0.0663
# cur epoch:84, cur loss:0.06861, best epoch:77, best loss:0.0663
# cur epoch:85, cur loss:0.06911, best epoch:77, best loss:0.0663
# cur epoch:86, cur loss:0.06891, best epoch:77, best loss:0.0663
# cur epoch:87, cur loss:0.06740, best epoch:77, best loss:0.0663
# cur epoch:88, cur loss:0.06698, best epoch:77, best loss:0.0663
# cur epoch:89, cur loss:0.06953, best epoch:77, best loss:0.0663
# cur epoch:90, cur loss:0.06715, best epoch:77, best loss:0.0663
# cur epoch:91, cur loss:0.06934, best epoch:77, best loss:0.0663
# cur epoch:92, cur loss:0.06580, best epoch:92, best loss:0.0658
# cur epoch:93, cur loss:0.06745, best epoch:92, best loss:0.0658
# cur epoch:94, cur loss:0.06550, best epoch:94, best loss:0.0655
# cur epoch:95, cur loss:0.06719, best epoch:94, best loss:0.0655
# cur epoch:96, cur loss:0.06964, best epoch:94, best loss:0.0655
# cur epoch:97, cur loss:0.06596, best epoch:94, best loss:0.0655
# cur epoch:98, cur loss:0.06654, best epoch:94, best loss:0.0655
# cur epoch:99, cur loss:0.06614, best epoch:94, best loss:0.0655
# cur epoch:100, cur loss:0.06823, best epoch:94, best loss:0.0655
# cur epoch:101, cur loss:0.06688, best epoch:94, best loss:0.0655
# cur epoch:102, cur loss:0.06617, best epoch:94, best loss:0.0655
# cur epoch:103, cur loss:0.06977, best epoch:94, best loss:0.0655
# cur epoch:104, cur loss:0.06721, best epoch:94, best loss:0.0655
# cur epoch:105, cur loss:0.06733, best epoch:94, best loss:0.0655
# cur epoch:106, cur loss:0.06557, best epoch:94, best loss:0.0655
# cur epoch:107, cur loss:0.06505, best epoch:107, best loss:0.0651
# cur epoch:108, cur loss:0.06696, best epoch:107, best loss:0.0651
# cur epoch:109, cur loss:0.07007, best epoch:107, best loss:0.0651
# cur epoch:110, cur loss:0.06766, best epoch:107, best loss:0.0651
# cur epoch:111, cur loss:0.06524, best epoch:107, best loss:0.0651
# cur epoch:112, cur loss:0.06534, best epoch:107, best loss:0.0651
# cur epoch:113, cur loss:0.06595, best epoch:107, best loss:0.0651
# cur epoch:114, cur loss:0.06599, best epoch:107, best loss:0.0651
# cur epoch:115, cur loss:0.06553, best epoch:107, best loss:0.0651
# cur epoch:116, cur loss:0.06502, best epoch:116, best loss:0.0650
# cur epoch:117, cur loss:0.06776, best epoch:116, best loss:0.0650
# cur epoch:118, cur loss:0.06890, best epoch:116, best loss:0.0650
# cur epoch:119, cur loss:0.06383, best epoch:119, best loss:0.0638

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Evaluation and Visualization

# %%
import seaborn as sns

def dice_multiclass(pred, target):

    smooth = 1.
    dices = []

    for idx in range(1,8):
        iflat = pred.contiguous().view(-1)
        tflat = target.contiguous().view(-1)

        iflat_temp = torch.zeros(iflat.size())
        tflat_temp= torch.zeros(iflat.size())

        iflat_temp[iflat==idx] = 1
        tflat_temp[tflat==idx] = 1

        intersection = (iflat_temp * tflat_temp).sum()

        A_sum = torch.sum(tflat_temp * iflat_temp)
        B_sum = torch.sum(tflat_temp * tflat_temp)

        dice = (2. * intersection + smooth) / (A_sum + B_sum + smooth) 
        dices.append(dice)
    
    return dices

import matplotlib.pyplot as plt 
# %matplotlib inline

def evaluation (model, valid_loader, criterion):
    model.eval()
    dice_acc=[]
    sum_loss = 0
    for inputs, actual in valid_loader:
        inputs = inputs.to(device)
        actual = actual.to(device)

        logit = model(inputs)
        pred = logit.argmax(dim=1)
        
        loss = criterion(logit,actual)
        sum_loss += loss.item()
    
        dice_ = dice_multiclass(pred, actual)
        dice_acc.append(dice_) 
    
    ip = inputs[0,0,:,:].detach().cpu().numpy()
    gt = actual[0].detach().cpu().numpy()
    pd = pred[0].detach().cpu().numpy() 
    
    plt.subplot(1,3,1)
    plt.title('input')
    plt.imshow(ip*255, cmap='gray')
    plt.subplot(1,3,2)
    plt.title('ground truth')
    plt.imshow(gt, cmap='gray')
    plt.subplot(1,3,3)
    plt.title('prediction')
    plt.imshow(pd, cmap='gray')
    plt.tight_layout()
    plt.show()

    return np.array(dice_acc), sum_loss/len(valid_loader)

model.load_state_dict(torch.load('best_model.pth'))
dice_acc, final_loss = evaluation (model, valid_loader,criterion)
ax = sns.boxplot(data=dice_acc)
final_dice = np.mean(dice_acc,0)
print("Dice:%.4f [seep1:%.4f,seep2:%.4f,seep3:%.4f,seep4:%.4f,seep5:%.4f,seep6:%.4f,seep7:%.4f], cross-entropy loss:%.4f" 
      %(np.mean(final_dice), final_dice[0],final_dice[1],final_dice[2],final_dice[3],final_dice[4],
        final_dice[5],final_dice[6],final_loss))
# Out:
# Dice:0.5840 [seep1:0.6247,seep2:0.3847,seep3:0.6522,seep4:0.6987,seep5:0.6140,seep6:0.3608,seep7:0.7531], cross-entropy loss:0.0638

# %% [markdown]
# In this project, I use U-Net to detect non-seep and different classes of seeps. U-Net is an encoder-decoder segmentation network which contains convolution blocks of convolution, ReLU and maxpooling layers, and corresponding de-convolutional blocks. <br>
# In dataloader, I split the dataset into 20% for validation and remainings are for training. Dataloader contains augmentation of random flipping and pixel normalization into 0-1 range. <br>
# In the final evaluation, average seep is 0.5840 and seep-7 is with best prediction among all classes.
